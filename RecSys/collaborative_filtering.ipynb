# %% [markdown]
# # 1. Загрузка и подготовка данных

# %%
import pandas as pd
import numpy as np

# %%
# !pip install surprise
# Out:
# Collecting surprise
#   Downloading surprise-0.1-py2.py3-none-any.whl (1.8 kB)
# Collecting scikit-surprise (from surprise)
#   Downloading scikit_surprise-1.1.4.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 1.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.25.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.11.4)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (pyproject.toml) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp310-cp310-linux_x86_64.whl size=2357237 sha256=e525c0f78a99d1bb7db10d2977fe5ba4e4c9444213485f1327014da88edcd147
#   Stored in directory: /root/.cache/pip/wheels/4b/3f/df/6acbf0a40397d9bf3ff97f582cc22fb9ce66adde75bc71fd54
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise, surprise
# Successfully installed scikit-surprise-1.1.4 surprise-0.1

# %%
# !wget 'https://files.grouplens.org/datasets/movielens/ml-latest-small.zip' -O  MovieLens.zip --no-check-certificate
# Out:
# --2024-06-24 19:38:51--  https://files.grouplens.org/datasets/movielens/ml-latest-small.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:443... connected.
# WARNING: cannot verify files.grouplens.org's certificate, issued by ‘CN=R3,O=Let's Encrypt,C=US’:
#   Issued certificate has expired.
# HTTP request sent, awaiting response... 200 OK
# Length: 978202 (955K) [application/zip]
# Saving to: ‘MovieLens.zip’
#
# MovieLens.zip       100%[===================>] 955.28K  5.65MB/s    in 0.2s
#
# 2024-06-24 19:38:52 (5.65 MB/s) - ‘MovieLens.zip’ saved [978202/978202]

# %%
# !unzip MovieLens.zip
# Out:
# Archive:  MovieLens.zip
#    creating: ml-latest-small/
#   inflating: ml-latest-small/links.csv
#   inflating: ml-latest-small/tags.csv
#   inflating: ml-latest-small/ratings.csv
#   inflating: ml-latest-small/README.txt
#   inflating: ml-latest-small/movies.csv

# %%
df_movies = pd.read_csv('ml-latest-small/movies.csv')
df_ratings = pd.read_csv('ml-latest-small/ratings.csv')

# %%
df_movies.shape, df_ratings.shape
# Out:
# ((9742, 3), (100836, 4))

# %%
df_movies_with_ratings = df_movies.join(
    df_ratings.set_index('movieId'),
    on='movieId',
    how='inner').reset_index(drop=True)

df_movies_with_ratings.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946
# 3      15     2.5  1510577970
# 4      17     4.5  1305696483

# %%
df_movies_with_ratings.shape
# Out:
# (100836, 6)

# %%
df_movies_with_ratings.title.nunique(), df_movies_with_ratings.userId.nunique()
# Out:
# (9719, 610)

# %% [markdown]
# # 2. Surprise

# %%
from surprise import Dataset
from surprise import Reader
from surprise import accuracy
from surprise.model_selection import train_test_split
from surprise.model_selection import cross_validate

# %%
dataset = pd.DataFrame({
    'uid': df_movies_with_ratings.userId,
    'iid': df_movies_with_ratings.title,
    'rating': df_movies_with_ratings.rating
})

dataset.head()
# Out:
#    uid               iid  rating
# 0    1  Toy Story (1995)     4.0
# 1    5  Toy Story (1995)     4.0
# 2    7  Toy Story (1995)     4.5
# 3   15  Toy Story (1995)     2.5
# 4   17  Toy Story (1995)     4.5

# %%
reader = Reader(rating_scale=(df_ratings.rating.min(), df_ratings.rating.max()))
data = Dataset.load_from_df(dataset, reader)

# %%
from surprise import SVD, SVDpp, KNNBaseline

# %%
def get_cv(model):
  cross_validate(model, data, measures=['RMSE'], cv=5, verbose=True)

# %%
def get_knn_cv(model_name, sim_options, max_range=[30, 40, 50], min_range=[1, 5, 10]):
  for max_k in max_range:
    for min_k in min_range:
      print(f'\n  max_k = {max_k}, min_k = {min_k}\n')
      model = model_name(k=max_k,
                          min_k = min_k,
                          sim_options=sim_options,
                          verbose=False,
                          random_state=42)
      get_cv(model)

# %% [markdown]
# ## SVD
#
# min RMSE (testset) = 0.8746 (mean)

# %%
from surprise import SVD

# %%
model = SVD(random_state=42)
get_cv(model)
# Out:
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8686  0.8805  0.8715  0.8742  0.8779  0.8746  0.0043
# Fit time          1.55    1.63    1.61    2.12    1.53    1.69    0.22
# Test time         0.16    0.23    0.19    0.26    0.11    0.19    0.05

# %% [markdown]
# ## KNNBaseline
#
# min RMSE (testset) = 0.8571 (mean)

# %%
from surprise import KNNBaseline

# %%
sim_options = {'name': 'pearson_baseline',
               'user_based': True}

# %%
get_knn_cv(KNNBaseline, sim_options)
# Out:
#   max_k = 30, min_k = 1
#
# Evaluating RMSE of algorithm KNNBaseline on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8781  0.8817  0.8769  0.8775  0.8766  0.8782  0.0018
# Fit time          0.50    0.54    0.54    0.51    0.56    0.53    0.02
# Test time         1.38    1.49    1.36    1.49    2.26    1.60    0.34
#
#   max_k = 30, min_k = 5
#
# Evaluating RMSE of algorithm KNNBaseline on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8464  0.8608  0.8568  0.8667  0.8642  0.8590  0.0071
# Fit time          0.51    0.51    0.55    0.56    0.55    0.54    0.02
# Test time         1.49    1.35    1.35    1.37    1.69    1.45    0.13
#
#   max_k = 30, min_k = 10
#
# Evaluating RMSE of algorithm KNNBaseline on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8472  0.8684  0.8474  0.8536  0.8692  0.8572  0.0098
# Fit time          0.65    0.50    0.53    0.52    0.53    0.55    0.05
# Test time         1.60    1.33    1.49    1.35    1.49    1.45    0.10
#
#   max_k = 40, min_k = 1
#
# Evaluating RMSE of algorithm KNNBaseline on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8765  0.8814  0.8773  0.8746  0.8779  0.8776  0.0022
# Fit time          0.61    0.50    0.52    0.52    0.64    0.56    0.06
# Test time         2.31    1.52    1.40    1.62    2.38    1.85    0.41
#
#   max_k = 40, min_k = 5
#
# Evaluating RMSE of algorithm KNNBaseline on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8473  0.8678  0.8567  0.8610  0.8612  0.8588  0.0068
# Fit time          0.65    0.55    0.85    0.53    0.51    0.62    0.13
# Test time         1.98    1.57    1.40    1.54    1.45    1.59    0.20
#
#   max_k = 40, min_k = 10
#
# Evaluating RMSE of algorithm KNNBaseline on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8513  0.8628  0.8551  0.8621  0.8545  0.8572  0.0045
# Fit time          0.58    0.53    0.51    0.51    0.51    0.53    0.03
# Test time         2.30    1.41    1.40    2.23    1.43    1.76    0.42
#
#   max_k = 50, min_k = 1
#
# Evaluating RMSE of algorithm KNNBaseline on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8810  0.8806  0.8775  0.8815  0.8712  0.8784  0.0038
# Fit time          0.59    0.98    0.53    0.51    0.53    0.63    0.18
# Test time         2.32    1.61    1.57    1.46    1.46    1.68    0.33
#
#   max_k = 50, min_k = 5
#
# Evaluating RMSE of algorithm KNNBaseline on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8665  0.8633  0.8562  0.8583  0.8536  0.8596  0.0047
# Fit time          0.60    0.52    0.65    0.56    0.56    0.58    0.04
# Test time         2.09    1.49    2.45    1.47    1.92    1.89    0.37
#
#   max_k = 50, min_k = 10
#
# Evaluating RMSE of algorithm KNNBaseline on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8595  0.8600  0.8661  0.8603  0.8398  0.8571  0.0090
# Fit time          0.64    0.51    0.54    0.53    0.53    0.55    0.05
# Test time         1.66    1.57    1.42    1.58    1.48    1.54    0.08

# %% [markdown]
# ## KNNBasic
#
# min RMSE (testset) = 0.9691 (mean)

# %%
from surprise import KNNBasic

# %%
sim_options = {'name': 'cosine',
               'user_based': True}

# %%
get_knn_cv(KNNBasic, sim_options)
# Out:
#   max_k = 30, min_k = 1
#
# Evaluating RMSE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9683  0.9736  0.9741  0.9697  0.9759  0.9723  0.0028
# Fit time          0.14    0.19    0.17    0.18    0.26    0.19    0.04
# Test time         1.48    1.19    1.16    1.81    1.53    1.43    0.24
#
#   max_k = 30, min_k = 5
#
# Evaluating RMSE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9649  0.9740  0.9707  0.9768  0.9610  0.9695  0.0058
# Fit time          0.14    0.19    0.18    0.17    0.17    0.17    0.01
# Test time         1.34    1.20    1.34    1.18    1.94    1.40    0.28
#
#   max_k = 30, min_k = 10
#
# Evaluating RMSE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9820  0.9840  0.9802  0.9754  0.9786  0.9800  0.0029
# Fit time          0.15    0.26    0.17    0.38    0.19    0.23    0.08
# Test time         1.83    1.47    1.21    1.60    1.19    1.46    0.24
#
#   max_k = 40, min_k = 1
#
# Evaluating RMSE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9750  0.9691  0.9709  0.9761  0.9723  0.9727  0.0026
# Fit time          0.15    0.18    0.25    0.17    0.17    0.19    0.03
# Test time         1.25    1.51    1.90    1.33    1.23    1.44    0.25
#
#   max_k = 40, min_k = 5
#
# Evaluating RMSE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9677  0.9666  0.9746  0.9723  0.9641  0.9691  0.0039
# Fit time          0.15    0.17    0.19    0.19    0.23    0.18    0.03
# Test time         1.22    1.36    1.24    1.57    1.84    1.44    0.23
#
#   max_k = 40, min_k = 10
#
# Evaluating RMSE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9854  0.9900  0.9687  0.9804  0.9758  0.9801  0.0074
# Fit time          0.13    0.17    0.19    0.17    0.17    0.17    0.02
# Test time         1.39    1.22    1.35    1.22    1.36    1.31    0.07
#
#   max_k = 50, min_k = 1
#
# Evaluating RMSE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9718  0.9790  0.9698  0.9701  0.9733  0.9728  0.0033
# Fit time          0.15    0.23    0.17    0.18    0.19    0.19    0.03
# Test time         1.38    2.03    1.29    1.39    1.26    1.47    0.28
#
#   max_k = 50, min_k = 5
#
# Evaluating RMSE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9717  0.9721  0.9767  0.9578  0.9716  0.9700  0.0064
# Fit time          0.14    0.17    0.19    0.28    0.19    0.19    0.05
# Test time         1.39    1.27    1.64    1.84    1.31    1.49    0.22
#
#   max_k = 50, min_k = 10
#
# Evaluating RMSE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9812  0.9842  0.9769  0.9842  0.9709  0.9794  0.0051
# Fit time          0.15    0.18    0.18    0.18    0.17    0.17    0.01
# Test time         1.43    1.29    1.41    1.30    2.03    1.49    0.27

# %% [markdown]
# ## KNNWithMeans
#
# min RMSE (testset) = 0.8902 (mean)

# %%
from surprise import KNNWithMeans

# %%
sim_options = {'name': 'pearson',
               'user_based': True}

# %%
get_knn_cv(KNNWithMeans, sim_options)
# Out:
#   max_k = 30, min_k = 1
#
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8910  0.8920  0.9051  0.8965  0.9003  0.8970  0.0052
# Fit time          0.27    0.27    0.24    0.36    0.28    0.28    0.04
# Test time         1.32    1.42    1.26    2.24    1.42    1.53    0.36
#
#   max_k = 30, min_k = 5
#
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8932  0.8943  0.8923  0.8838  0.8909  0.8909  0.0037
# Fit time          0.69    0.25    0.26    0.27    0.35    0.36    0.17
# Test time         2.11    1.42    1.33    1.57    1.97    1.68    0.31
#
#   max_k = 30, min_k = 10
#
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8902  0.8977  0.8975  0.9004  0.9014  0.8974  0.0039
# Fit time          0.33    0.33    0.29    0.25    0.24    0.29    0.04
# Test time         1.87    1.43    1.42    1.29    1.50    1.50    0.19
#
#   max_k = 40, min_k = 1
#
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8971  0.8959  0.8910  0.8954  0.8994  0.8957  0.0027
# Fit time          0.36    0.27    0.26    0.25    0.25    0.28    0.04
# Test time         2.42    1.36    1.44    1.31    1.45    1.59    0.42
#
#   max_k = 40, min_k = 5
#
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8954  0.8981  0.8824  0.8878  0.8919  0.8911  0.0055
# Fit time          0.27    0.36    0.27    0.27    0.27    0.29    0.04
# Test time         1.45    2.02    1.37    1.33    1.44    1.52    0.25
#
#   max_k = 40, min_k = 10
#
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8948  0.8983  0.8981  0.8990  0.8951  0.8971  0.0017
# Fit time          0.24    0.25    0.39    0.29    0.28    0.29    0.06
# Test time         1.30    1.47    2.27    1.48    1.35    1.57    0.35
#
#   max_k = 50, min_k = 1
#
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9029  0.8944  0.8856  0.8979  0.8961  0.8954  0.0056
# Fit time          0.28    0.28    0.29    0.31    0.25    0.28    0.02
# Test time         1.53    1.37    1.49    2.37    1.54    1.66    0.36
#
#   max_k = 50, min_k = 5
#
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8918  0.8898  0.8838  0.8970  0.8885  0.8902  0.0043
# Fit time          0.27    0.25    0.27    0.26    0.26    0.26    0.00
# Test time         1.35    1.35    1.56    1.39    2.41    1.61    0.41
#
#   max_k = 50, min_k = 10
#
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8970  0.8939  0.8987  0.8897  0.9079  0.8975  0.0060
# Fit time          0.23    0.25    0.26    0.26    0.40    0.28    0.06
# Test time         1.35    1.51    1.40    1.53    2.19    1.59    0.31

# %% [markdown]
# ## BaselineOnly
#
# min RMSE (testset) = 0.8670 (mean)

# %%
from surprise import BaselineOnly

# %% [markdown]
# 'method': 'als'

# %%
bsl_options = {'method': 'als',
               'n_epochs': 5}

# %%
model = BaselineOnly(bsl_options=bsl_options, verbose=False)
get_cv(model)
# Out:
# Evaluating RMSE of algorithm BaselineOnly on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8712  0.8814  0.8700  0.8694  0.8740  0.8732  0.0044
# Fit time          0.20    0.22    0.24    0.22    0.21    0.22    0.01
# Test time         0.08    0.20    0.17    0.20    0.07    0.14    0.06

# %% [markdown]
# 'method': 'sgd'

# %%
bsl_options = {'method': 'sgd',
               'learning_rate': 0.01}

# %%
model = BaselineOnly(bsl_options=bsl_options, verbose=False)
get_cv(model)
# Out:
# Evaluating RMSE of algorithm BaselineOnly on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8663  0.8641  0.8678  0.8709  0.8661  0.8670  0.0022
# Fit time          0.65    0.65    0.65    0.65    0.64    0.65    0.01
# Test time         0.19    0.07    0.20    0.07    0.19    0.15    0.06

# %% [markdown]
# # Выводы

# %% [markdown]
# Лучше всех справился **KNNBaseline** с параметрами
#
# ```
# (k = 50, min_k = 10, 'user_based': True)
# ```
#
# минимальное среднее RMSE на тестовой выборке = 0.8571.

# %% [markdown]
# В случае **BaselineOnly** с параметрами
#
# ```
# ('method': 'sgd', 'learning_rate': 0.01)
# ```
#
#  минимальное среднее RMSE = 0.8670
